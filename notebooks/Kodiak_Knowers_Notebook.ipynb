# %% [markdown]
# ## **Abstract**

# %% [markdown]
# **"How are social media use patterns associated with mental health, sleep quality, and productivity among young adults?"**

# %% [markdown]
# ## Group Members
#
# 1. Jose Paulo Honrado
# 2. King Mejia
# 3. Mikael Paule
# 4. Heart rodrigo
# 5. Kenji Yasuda

# %% [markdown]
# ## **Dataset Description**

# %% [markdown]
# ## **Data Cleaning & Preprocessing**

# %% [markdown]
# ### Imports and Setup

# %% [markdown]
# First, clone the github repository to gain access to the datasets

# %%
# !git clone https://github.com/klyckman/CSMODEL.git
# Out:
# Cloning into 'CSMODEL'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 25 (delta 5), reused 20 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), 33.68 KiB | 1.40 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd CSMODEL
# !ls data/raw
# Out:
# /content/CSMODEL
#  Mental_Health_and_Social_Media_Balance_Dataset.csv
#  smmh.csv
# 'Social Media Impact on Daily Lives.csv'

# %%
import pandas as pd
import numpy as np
from pathlib import Path

DATA_DIR = Path("data/raw")

csv_files = list(DATA_DIR.glob("*.csv"))

datasets = {}

for file in csv_files:
    datasets[file.stem] = pd.read_csv(file)
    print(file.stem, datasets[file.stem].shape)

datasets.keys()
# Out:
# Mental_Health_and_Social_Media_Balance_Dataset (500, 10)
# smmh (481, 21)
# Social Media Impact on Daily Lives (522, 16)
# dict_keys(['Mental_Health_and_Social_Media_Balance_Dataset', 'smmh', 'Social Media Impact on Daily Lives'])

# %% [markdown]
# ## **Research Question & Exploratory Data Analysis**

# %% [markdown]
# ## **Summary, Conclusions, and Recommendations**

# %% [markdown]
# ## **References & Disclosures**
